# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pylab import rcParams

# %matplotlib inline
rcParams['figure.figsize'] = 5,4
sns.set_style('whitegrid')

df = sns.load_dataset("iris")
df.columns = ['comp da cepa', 'larg da cepa', 'comp da pétala', 'larg da pétala', 'espécie']
df.head()
# Out:
#    comp da cepa  larg da cepa  comp da pétala  larg da pétala espécie
# 0           5.1           3.5             1.4             0.2  setosa
# 1           4.9           3.0             1.4             0.2  setosa
# 2           4.7           3.2             1.3             0.2  setosa
# 3           4.6           3.1             1.5             0.2  setosa
# 4           5.0           3.6             1.4             0.2  setosa

# %%
sns.boxplot(data=df, x='espécie', y='comp da cepa', palette='hls')
# Out:
# <AxesSubplot:xlabel='espécie', ylabel='comp da cepa'>

# %%
sns.pairplot(df, hue='espécie', palette='hls')
